# %%
# dataframe manipulation, data sourcing, decorators (optional)

# Potential dataset sources
# https://www.kaggle.com/
# https://archive.ics.uci.edu/
# https://paperswithcode.com/datasets
# https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data, quick overview

# %%
# https://www.kaggle.com/datasets/asaniczka/video-game-sales-2024
vgchartz = pd.read_csv('./vgchartz-2024.csv')

# %%
vgchartz.info() # Look for column types and null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB

# %%
vgchartz[::2] # get every second item
# Out:
#                                                      img  \
# 0          /games/boxart/full_6510540AmericaFrontccc.jpg
# 2                            /games/boxart/827563ccc.jpg
# 4          /games/boxart/full_4990510AmericaFrontccc.jpg
# 6      /games/boxart/full_call-of-duty-black-ops_5Ame...
# 8          /games/boxart/full_1977964AmericaFrontccc.jpg
# ...                                                  ...
# 64006                          /games/boxart/default.jpg
# 64008                          /games/boxart/default.jpg
# 64010        /games/boxart/full_2294305JapanFrontccc.jpg
# 64012      /games/boxart/full_8031506AmericaFrontccc.jpg
# 64014        /games/boxart/full_6012940JapanFrontccc.png
#
#                                  title console         genre  \
# 0                   Grand Theft Auto V     PS3        Action
# 2          Grand Theft Auto: Vice City     PS2        Action
# 4            Call of Duty: Black Ops 3     PS4       Shooter
# 6              Call of Duty: Black Ops    X360       Shooter
# 8           Call of Duty: Black Ops II    X360       Shooter
# ...                                ...     ...           ...
# 64006                   Without Within      PC  Visual Novel
# 64008                 Without Within 3      PC  Visual Novel
# 64010               World End Syndrome     PS4  Visual Novel
# 64012                     Yoru, Tomosu     PS4  Visual Novel
# 64014  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# 2            Rockstar Games        Rockstar North           9.6        16.15
# 4                Activision              Treyarch           8.1        15.09
# 6                Activision              Treyarch           8.8        14.74
# 8                Activision              Treyarch           8.4        13.86
# ...                     ...                   ...           ...          ...
# 64006           InvertMouse           InvertMouse           NaN          NaN
# 64008           InvertMouse           InvertMouse           NaN          NaN
# 64010      Arc System Works      Arc System Works           NaN          NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64014          Idea Factory               Otomate           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0          6.37      0.99       9.85         3.12   2013-09-17         NaN
# 2          8.41      0.47       5.49         1.78   2002-10-28         NaN
# 4          6.18      0.41       6.05         2.44   2015-11-06  2018-01-14
# 6          9.76      0.11       3.73         1.14   2010-11-09         NaN
# 8          8.27      0.07       4.32         1.20   2012-11-13  2018-04-07
# ...         ...       ...        ...          ...          ...         ...
# 64006       NaN       NaN        NaN          NaN   2015-01-22  2018-12-25
# 64008       NaN       NaN        NaN          NaN   2018-05-03  2018-12-25
# 64010       NaN       NaN        NaN          NaN   2018-04-26  2019-04-03
# 64012       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64014       NaN       NaN        NaN          NaN   2019-02-28  2019-02-24
#
# [32008 rows x 14 columns]

# %%
vgchartz.iloc[::5, -3:] # using numpy comma separated slices, accessing every 5th row
                        # of only the last two columns
# Out:
#        other_sales release_date last_update
# 0             3.12   2013-09-17         NaN
# 5             1.33   2011-11-08         NaN
# 10            1.28   2009-11-10         NaN
# 15            1.73   2017-09-29  2018-04-02
# 20            0.98   2013-11-05  2018-03-21
# ...            ...          ...         ...
# 63995          NaN   2020-09-10  2020-07-31
# 64000          NaN   2017-06-06  2018-12-17
# 64005          NaN   2022-12-08  2023-07-05
# 64010          NaN   2018-04-26  2019-04-03
# 64015          NaN          NaN  2023-09-29
#
# [12804 rows x 3 columns]

# %%
vgchartz.loc[::5, ['other_sales', 'release_date']] # using loc - second argument is 
                                                   # a list of column names
# Out:
#        other_sales release_date
# 0             3.12   2013-09-17
# 5             1.33   2011-11-08
# 10            1.28   2009-11-10
# 15            1.73   2017-09-29
# 20            0.98   2013-11-05
# ...            ...          ...
# 63995          NaN   2020-09-10
# 64000          NaN   2017-06-06
# 64005          NaN   2022-12-08
# 64010          NaN   2018-04-26
# 64015          NaN          NaN
#
# [12804 rows x 2 columns]

# %%
vgchartz.columns # Review column names
# Out:
# Index(['img', 'title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'total_sales', 'na_sales', 'jp_sales', 'pal_sales',
#        'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## Finding total sales by title, augmenting original data

# %%
vgchartz[['title', 'total_sales']]
# Out:
#                                   title  total_sales
# 0                    Grand Theft Auto V        20.32
# 1                    Grand Theft Auto V        19.39
# 2           Grand Theft Auto: Vice City        16.15
# 3                    Grand Theft Auto V        15.86
# 4             Call of Duty: Black Ops 3        15.09
# ...                                 ...          ...
# 64011             XBlaze Lost: Memories          NaN
# 64012                      Yoru, Tomosu          NaN
# 64013                      Yoru, Tomosu          NaN
# 64014   Yunohana SpRING! ~Mellow Times~          NaN
# 64015  Yurukill: The Calumniation Games          NaN
#
# [64016 rows x 2 columns]

# %%
vgchartz.groupby('title').total_sales
# Out:
# title
# "Nuke It"                        NaN
# #DRIVE Rally                     NaN
# #IDARB                           NaN
# #killallzombies                  NaN
# '70s Robot Anime: Geppy-X        NaN
#                                 ...
# yOm                              NaN
# yOm_fury                         NaN
# ¡Shin Chan Flipa en colores!    0.14
# じんるいのみなさまへ                       NaN
# レミロア~少女と異世界と魔導書                  NaN
# Name: total_sales, Length: 39798, dtype: float64

# %%
sales_sorted = vgchartz.sort_values(by='total_sales', ascending=False)

# %%
sales_grouped = pd.DataFrame(vgchartz.groupby('title')
                                     .total_sales.sum()
                                     .sort_values(ascending=False))

# %%
sales_grouped = sales_grouped.reset_index()

# %%
sales_grouped['combined_total_sales'] = sales_grouped.total_sales
sales_grouped = sales_grouped.drop(columns='total_sales')
sales_grouped
# Out:
#                                                    title  combined_total_sales
# 0                                     Grand Theft Auto V                 64.29
# 1                                Call of Duty: Black Ops                 30.99
# 2                         Call of Duty: Modern Warfare 3                 30.71
# 3                             Call of Duty: Black Ops II                 29.59
# 4                                   Call of Duty: Ghosts                 28.80
# ...                                                  ...                   ...
# 39793  Hisshou Pachinko*Pachi-Slot Kouryaku Series Vo...                  0.00
# 39794  Hisshou Pachinko*Pachi-Slot Kouryaku Series Vo...                  0.00
# 39795  Hisshou Pachinko*Pachi-Slot Kouryaku Series Vo...                  0.00
# 39796  Hisshou Pachinko*Pachi-Slot Kouryaku Series Vo...                  0.00
# 39797                                    レミロア~少女と異世界と魔導書                  0.00
#
# [39798 rows x 2 columns]

# %%
vgchartz.total_sales = sales_grouped.total_sales # The size and order do not match

# %%
vgchartz['total_sales'].isna().sum() # Now we have tons of null values!
# Out:
# 24218

# %%
# Reset the original dataframe
vgchartz = pd.read_csv('./vgchartz-2024.csv')

# %%
vgchartz
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# 1            Rockstar Games        Rockstar North           9.7        19.39
# 2            Rockstar Games        Rockstar North           9.6        16.15
# 3            Rockstar Games        Rockstar North           NaN        15.86
# 4                Activision              Treyarch           8.1        15.09
# ...                     ...                   ...           ...          ...
# 64011           Aksys Games      Arc System Works           NaN          NaN
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64013  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64014          Idea Factory               Otomate           NaN          NaN
# 64015               Unknown            G.rev Ltd.           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0          6.37      0.99       9.85         3.12   2013-09-17         NaN
# 1          6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2          8.41      0.47       5.49         1.78   2002-10-28         NaN
# 3          9.06      0.06       5.33         1.42   2013-09-17         NaN
# 4          6.18      0.41       6.05         2.44   2015-11-06  2018-01-14
# ...         ...       ...        ...          ...          ...         ...
# 64011       NaN       NaN        NaN          NaN   2016-08-11  2019-01-28
# 64012       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64013       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64014       NaN       NaN        NaN          NaN   2019-02-28  2019-02-24
# 64015       NaN       NaN        NaN          NaN          NaN  2023-09-29
#
# [64016 rows x 14 columns]

# %%
df = pd.merge(vgchartz, sales_grouped, on='title')

# %% [markdown]
# ---

# %% [markdown]
# ## Looking at the ratio of NA to JP sales, sorting/filtering

# %%
df['NA_JP_ratio'] = df.na_sales / df.jp_sales

# %%
america = df[(df.NA_JP_ratio >= 10) & (df.NA_JP_ratio < float('inf'))].sort_values('NA_JP_ratio', ascending=False)

# %%
america[america.title.str.contains('Grand Theft Auto')]
# Out:
#                                                 img  \
# 3     /games/boxart/full_8047513AmericaFrontccc.jpg
# 2     /games/boxart/full_9218923AmericaFrontccc.jpg
# 58    /games/boxart/full_1182151AmericaFrontccc.jpg
# 1188  /games/boxart/full_7346149AmericaFrontccc.jpg
# 315                    /games/boxart/1161187ccc.jpg
# 47                     /games/boxart/3570928ccc.jpg
# 136   /games/boxart/full_1027141AmericaFrontccc.jpg
# 1439                   /games/boxart/6725603ccc.jpg
# 8                       /games/boxart/827563ccc.jpg
# 135                    /games/boxart/1340019ccc.jpg
# 2727  /games/boxart/full_7823563AmericaFrontccc.jpg
# 59    /games/boxart/full_1729769AmericaFrontccc.jpg
# 314   /games/boxart/full_1162504AmericaFrontccc.jpg
# 1     /games/boxart/full_5563178AmericaFrontccc.jpg
#
#                                              title console      genre  \
# 3                               Grand Theft Auto V    XOne     Action
# 2                               Grand Theft Auto V    X360     Action
# 58                             Grand Theft Auto IV    X360     Action
# 1188  Grand Theft Auto: Episodes from Liberty City    X360  Adventure
# 315            Grand Theft Auto: Vice City Stories     PS2     Action
# 47                            Grand Theft Auto III     PS2     Action
# 136         Grand Theft Auto: Liberty City Stories     PS2     Action
# 1439                              Grand Theft Auto      PS     Action
# 8                      Grand Theft Auto: Vice City     PS2     Action
# 135         Grand Theft Auto: Liberty City Stories     PSP     Action
# 2727              Grand Theft Auto: Chinatown Wars      DS  Adventure
# 59                             Grand Theft Auto IV     PS3     Action
# 314            Grand Theft Auto: Vice City Stories     PSP     Action
# 1                               Grand Theft Auto V     PS4     Action
#
#                  publisher             developer  critic_score  total_sales  \
# 3           Rockstar Games        Rockstar North           9.0         8.72
# 2           Rockstar Games        Rockstar North           NaN        15.86
# 58          Rockstar Games        Rockstar North          10.0        11.09
# 1188        Rockstar Games        Rockstar North           9.0         2.60
# 315         Rockstar Games        Rockstar Leeds           NaN         0.97
# 47          Rockstar Games            DMA Design           9.5        13.10
# 136         Rockstar Games        Rockstar Leeds           8.3         3.54
# 1439  Take-Two Interactive            DMA Design           6.0         2.32
# 8           Rockstar Games        Rockstar North           9.6        16.15
# 135         Rockstar Games        Rockstar Leeds           8.8         7.72
# 2727        Rockstar Games  Rockstar Leeds/North           9.5         1.33
# 59          Rockstar Games        Rockstar North          10.0        10.57
# 314         Rockstar Games        Rockstar Leeds           8.4         5.08
# 1           Rockstar Games        Rockstar North           9.7        19.39
#
#       na_sales  jp_sales  pal_sales  other_sales release_date last_update  \
# 3         4.70      0.01       3.25         0.76   2014-11-18  2018-04-11
# 2         9.06      0.06       5.33         1.42   2013-09-17         NaN
# 58        6.80      0.14       3.11         1.04   2008-04-29         NaN
# 1188      1.08      0.03       1.22         0.27   2009-10-29         NaN
# 315       0.78      0.03       0.03         0.13   2007-03-05         NaN
# 47        6.99      0.30       4.51         1.30   2001-10-23         NaN
# 136       1.56      0.07       1.40         0.50   2006-06-06         NaN
# 1439      0.79      0.04       1.35         0.14   1998-06-30         NaN
# 8         8.41      0.47       5.49         1.78   2002-10-28         NaN
# 135       2.90      0.24       2.83         1.74   2005-10-25         NaN
# 2727      0.58      0.05       0.56         0.14   2009-03-17         NaN
# 59        4.79      0.44       3.73         1.62   2008-04-29         NaN
# 314       1.70      0.16       2.03         1.19   2006-10-31         NaN
# 1         6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
#
#       combined_total_sales  NA_JP_ratio
# 3                    64.29   470.000000
# 2                    64.29   151.000000
# 58                   22.53    48.571429
# 1188                  4.78    36.000000
# 315                   6.05    26.000000
# 47                   13.11    23.300000
# 136                  11.26    22.285714
# 1439                  2.56    19.750000
# 8                    16.19    17.893617
# 135                  11.26    12.083333
# 2727                  2.41    11.600000
# 59                   22.53    10.886364
# 314                   6.05    10.625000
# 1                    64.29    10.100000

# %% [markdown]
# ---

# %% [markdown]
# ## Fun with decorators
#
# Terminology: decorators take advantage of [closures](https://en.wikipedia.org/wiki/Closure_(computer_programming)). Accessing special variables like `__closure__` and `__name__` while the program is running (aka "during runtime") is a form of [reflection](https://en.wikipedia.org/wiki/Reflective_programming).

# %%
# Making a simple execution counter decorator 
# V1, no global variables, count stored in the closure.


# Uncomment the print statements to see when each code block runs
def exc_counter(func):
    count = 0
#     print('ran exc_counter')
    def wrapper(*args, **kwargs):
        nonlocal count 
#         print('called the wrapper')
        count += 1
        print('Called', func.__name__, count, 'times')
        func(*args, **kwargs)
    return wrapper


@exc_counter
def hello(name):
    return 'hello ' + name
    
    
@exc_counter
def add(x, y):
    return x + y

# Simulate calling the functions a bunch of times
for _ in range(10):
    hello('_')
for _ in range(25):
    add(1,3)
# Out:
# Called hello 1 times
# Called hello 2 times
# Called hello 3 times
# Called hello 4 times
# Called hello 5 times
# Called hello 6 times
# Called hello 7 times
# Called hello 8 times
# Called hello 9 times
# Called hello 10 times
# Called add 1 times
# Called add 2 times
# Called add 3 times
# Called add 4 times
# Called add 5 times
# Called add 6 times
# Called add 7 times
# Called add 8 times
# Called add 9 times
# Called add 10 times
# Called add 11 times
# Called add 12 times
# Called add 13 times
# Called add 14 times
# Called add 15 times
# Called add 16 times
# Called add 17 times
# Called add 18 times
# Called add 19 times
# Called add 20 times
# Called add 21 times
# Called add 22 times
# Called add 23 times
# Called add 24 times
# Called add 25 times

# %%
hello('name') # 11 times
add(1,2) # 26 times
# Out:
# Called hello 11 times
# Called add 26 times

# %%
# We can access their values directly, but it's not recommended!
print(add.__closure__[0].cell_contents)
print(hello.__closure__[0].cell_contents)
# Out:
# 26
# 11

# %%
register
# Out:
# {'hello': 4, 'add': 2}

# %%
# V2, better option if we want to maintain access to the values 
# used by our decorators: register in a global container

register = {}

def exc_counter(func):
    # Create an entry in the dictionary and set it to 0
    register[func.__name__] = 0

    def wrapper(*args, **kwargs):
        # Access that entry and increment it each call
        register[func.__name__] += 1
        func(*args, **kwargs)
    return wrapper


@exc_counter
def hello(name):
    return 'hello' + name
    
    
@exc_counter
def add(x, y):
    return x + y
    
# Simulate calling the functions a bunch of times
for _ in range(10):
    hello('_')
for _ in range(25):
    add(1,3)

# %%
print(register) # {'hello': 10, 'add': 25}
# Out:
# {'hello': 10, 'add': 25}
